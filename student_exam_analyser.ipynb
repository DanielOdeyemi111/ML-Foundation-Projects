# %% [markdown]
# ## Exam Score Analysis

# %%
import pandas as pd
import numpy as np

# %%
random_scores = np.random.randint(40, 100, size = 30)
random_scores
# Out:
# array([64, 52, 84, 79, 74, 58, 58, 78, 72, 96, 96, 40, 61, 42, 46, 46, 73,
#        48, 45, 59, 87, 97, 68, 43, 54, 71, 65, 56, 50, 85], dtype=int32)

# %%
student_name = np.array("Ade")
student_name
# Out:
# array('Ade', dtype='<U3')

# %%
student_data = pd.DataFrame({"Names" : student_name, "Scores" : random_scores})
student_data
# Out:
#    Names  Scores
# 0    Ade      64
# 1    Ade      52
# 2    Ade      84
# 3    Ade      79
# 4    Ade      74
# 5    Ade      58
# 6    Ade      58
# 7    Ade      78
# 8    Ade      72
# 9    Ade      96
# 10   Ade      96
# 11   Ade      40
# 12   Ade      61
# 13   Ade      42
# 14   Ade      46
# 15   Ade      46
# 16   Ade      73
# 17   Ade      48
# 18   Ade      45
# 19   Ade      59
# 20   Ade      87
# 21   Ade      97
# 22   Ade      68
# 23   Ade      43
# 24   Ade      54
# 25   Ade      71
# 26   Ade      65
# 27   Ade      56
# 28   Ade      50
# 29   Ade      85
